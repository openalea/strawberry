# %% [markdown]
# # Convert Strawberry Data to MTG

# %% [markdown]
# **Authors** : Marc Labadie, Christophe Pradal

# %%
from openalea.deploy.shared_data import shared_data
import strawberry
from strawberry.reader import Reader, strawberry2mtg 
from openalea.mtg import MTG, fat_mtg

# %%
files = shared_data(strawberry).glob('*.csv')
fn = files[0]
print shared_data(strawberry)
# Out:
# z:\g1\marc-labadie\python\strawberry\share\data

# %% [markdown]
# Reading the file and create an MTG

# %%
g = MTG()

# %%
class Reader(object):
    sep = ';'
    
    labels = {'C' : (2, 'Crown'), 
              'F' : (3, 'Phytomer'), 
              's' : (2, 'Runner'), 
              'b': (),
              'BT' : (3, 'TerminalBud'),
              'HT' : (3, 'Inflorescence'),
             }
    
    def __init__(self, filename):
        self.fn = filename
        self.props = [] # property names in a specific order
        self.types = []
        self.line_no = -1
        self.prop_no = -1

    
    def read(self):
        f = open(self.fn)
        content = f.read()
        f.close()
        self.content = [line.strip() for line in content.split('\n')]

        
    def header(self):
        """ Read the properties """
        
        sep = self.sep
        line_no = 0
        for l in self.content:
            line = [item.strip() for item in l.split(sep)]
            if line[0].startswith('Axis_') and  line[1].startswith('Axis_'):
                print '\t'.join(line)
                break
            line_no += 1
            
        self.line_no = line_no
        self.prop_no = self.line_no
        
        self.props = [item.strip() for item in self.content[line_no].split(';')]
        
        # Rename
        props = []
        com_rank = 0
        for i, prop in enumerate(self.props):
            if prop.startswith('Axe_'):
                prop = prop.replace('Axe_', 'Axis_')
            if prop.lower().startswith('com'):
                com_rank += 1
                prop = prop.lower()[:3]+'_'+str(com_rank)
                prop = prop.capitalize()
            props.append(prop)
        self.props = props
        
        self.prop_index = sum(1 for p in self.props if p.startswith('Axis_'))-1
        self.props = self.props[self.prop_index:]

    def __update_axis(self, first):
        n = len(self._axis_vid) 
        if n == first:
            self._axis_vid.append(self._vid)
        elif n == first+1:
            self._axis_vid[first] = self._vid
        else:
            print "ERROR", first, n, self._axis_vid

    def read_line(self):
        """
        Read one line
        """

        g = self.g
        self.line_no += 1
        n = len(self.content)
        if self.line_no >= n:
            return
        
        l = self.content[self.line_no]
        line = [item.strip() for item in l.split(self.sep)]
        if not line:
            return
        
        code = line[:self.prop_index]
        props = line[self.prop_index:]
        
        # TODO : convert properties to their own type
        current_props = dict(zip(self.props, props))
        
        if not filter(None, code):
            return
        
        first = 0
        for item in code:
            if not item:
                first += 1
            else:
                break
        
        if first >= self.prop_index:
            return
    
        
        label = code[first]
        info = self.labels.get(label, None)
        
        if info is None:
            raise 'Line %d: Label %s is not managed'%(self.line_no, label)
        elif not info:
            pass
        else:
            scale, label = self.labels[label]
            
        prev_scale = self._scale
        prev_order = self._order
        
        cur_order = first
        
        if cur_order == prev_order:
            if scale == prev_scale:
                pid = self._axis_vid[cur_order]
                self._vid = g.add_child(pid, label=label, edge_type='<', **current_props)
                self.__update_axis(first)
            else: 
                # TODO
                #pid = self._axis_vid[cur_order-1]
                pass
        elif cur_order > prev_order:
            if scale == prev_scale:
                pid = self._axis_vid[prev_order]
                self._vid = g.add_child(pid, label=label, edge_type='+', **current_props)
                self.__update_axis(first)
            else: 
                # TODO
                #pid = self._axis_vid[cur_order-1]
                pass
        else:
            pid = self._axis_vid[cur_order]
            self._vid = g.add_child(pid, label=label, edge_type='<', **current_props)
            self._axis_vid[cur_order] = self._vid
            if len(self._axis_vid) > cur_order:
                del self._axis_vid[cur_order+1:]
            
        self._order = cur_order
        
    def build_mtg(self):
        """ Build an MTG structure from data.
        
        The MTG is composed of 3 scales: Plant, Crown, Phytomer
        
        """
        self._axis_vid = []
        
        self.g = MTG()
        g = self.g
        
        # build 2 elements: P plante and C crown
        #self._vid = plant_id = g.add_component(g.root, label='Plant')
        # add crown
        #self._vid = g.add_component(self._vid, label='Crown')
        self._order = 0
        self._scale = 3
        self._vid = g.add_component(g.root, label='Phytomer')
        self._axis_vid.append(self._vid) 
        print self._vid
        
        nb_lines = len(self.content) - self.prop_no
        for i in range(nb_lines):
            self.read_line()
        
        self.g = fat_mtg(g)
        
    def parse(self):
        """ Read the file and build the MTG """
        self.read()
        self.header()
        self.build_mtg()
        return self.g

# %%
#%pdb on
reader = Reader(fn)
g = reader.parse()
# Out:
# Axis_1	Axis_2	Axe_3	Axis_4	Axis_5	Axis_6	leaf_area	leaf_perimeter	Lobe_C_H	Lobe_C_L	Lobe_G_H	Lobe_G_L	Leaf_area_algo	Com.	harvest_fruit	fruit_aborded	Total_ruit	com.
# 1
# ERROR 3 1 [46]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-560c4ff7ec70> in <module>()
#       1 #%pdb on
#       2 reader = Reader(fn)
# ----> 3 g = reader.parse()
#
# <ipython-input-11-c62e063ed9b8> in parse(self)
#     176         self.read()
#     177         self.header()
# --> 178         self.build_mtg()
#     179         return self.g
#     180
#
# <ipython-input-11-c62e063ed9b8> in build_mtg(self)
#     168         nb_lines = len(self.content) - self.prop_no
#     169         for i in range(nb_lines):
# --> 170             self.read_line()
#     171
#     172         self.g = fat_mtg(g)
#
# <ipython-input-11-c62e063ed9b8> in read_line(self)
#     137                 pass
#     138         else:
# --> 139             pid = self._axis_vid[cur_order]
#     140             self._vid = g.add_child(pid, label=label, edge_type='<', **current_props)
#     141             self._axis_vid[cur_order] = self._vid
#
# IndexError: list index out of range

# %%
g.display()
print fn
# Out:
# MTG : nb_vertices=69, nb_scales=2
# /Phytomer			(id=1)
# ^<Phytomer			(id=2)
# ^<Phytomer			(id=3)
# ^<Phytomer			(id=4)
# 	+Phytomer			(id=5)
# 	^<Phytomer			(id=6)
# 	^<Phytomer			(id=7)
# 	^<Phytomer			(id=8)
# 	^<Phytomer			(id=9)
# 	^<Phytomer			(id=10)
# 	^<Phytomer			(id=11)
# 	^<Phytomer			(id=12)
# 		+Phytomer			(id=13)
# 		^<Phytomer			(id=14)
# 		^<Phytomer			(id=15)
# 		^<Phytomer			(id=16)
# 			+Phytomer			(id=17)
# 			^<Phytomer			(id=18)
# 			^<Phytomer			(id=19)
# 			^<Phytomer			(id=20)
# 			^<TerminalBud			(id=21)
# 		^<Phytomer			(id=22)
# 			+Phytomer			(id=23)
# 			^<Phytomer			(id=24)
# 			^<Phytomer			(id=25)
# 			^<Phytomer			(id=26)
# 			^<Phytomer			(id=27)
# 			^<Phytomer			(id=28)
# 			^<Phytomer			(id=29)
# 			^<TerminalBud			(id=30)
# 		^<Inflorescence			(id=31)
# 	^<Inflorescence			(id=32)
# ^<Phytomer			(id=33)
# ^<Phytomer			(id=34)
# ^<Phytomer			(id=35)
# ^<Phytomer			(id=36)
# 	+Phytomer			(id=37)
# 	^<Phytomer			(id=38)
# 	^<Phytomer			(id=39)
# 		+Phytomer			(id=40)
# 		^<Phytomer			(id=41)
# 		^<Phytomer			(id=42)
# 			+Phytomer			(id=43)
# 			^<Phytomer			(id=44)
# 			^<Phytomer			(id=45)
# 			^<Phytomer			(id=46)
# 			^<Phytomer			(id=47)
# 			^<TerminalBud			(id=48)
# 		^<Inflorescence			(id=49)
# 	^<Inflorescence			(id=50)
# ^<Phytomer			(id=51)
# ^<Phytomer			(id=52)
# ^<Phytomer			(id=53)
# 	+Phytomer			(id=54)
# 		+Phytomer			(id=55)
# 			+Phytomer			(id=56)
# 			^<Phytomer			(id=57)
# 			^<Phytomer			(id=58)
# 			^<Phytomer			(id=59)
# 			^<Phytomer			(id=60)
# 			^<Inflorescence			(id=61)
# 		^<Phytomer			(id=62)
# 			+Phytomer			(id=63)
# 			^<Phytomer			(id=64)
# 			^<Inflorescence			(id=65)
# 		^<Inflorescence			(id=66)
# 	^<Inflorescence			(id=67)
# ^<Inflorescence			(id=68)
# z:\g1\marc-labadie\python\strawberry\share\data\Cir107_1_10.csv

# %%
gs = [strawberry2mtg(fn) for fn in files]
# Out:
# Axis_1	Axis_2	Axe_3	Axis_4	Axis_5	leaf_area	leaf_perimeter	Lobe_C_H	Lobe_C_L	Lobe_G_H	Lobe_G_L	Leaf_area_algo	Com.	harvest_fruit	fruit_aborded	Total_ruit	com.
# Axis_1	Axis_2	Axe_3	Axis_4	Axis_5	leaf_area	leaf_perimeter	Lobe_C_H	Lobe_C_L	Lobe_G_H	Lobe_G_L	Leaf_area_algo	Com.	harvest_fruit	fruit_aborded	Total_ruit	com.
# Axis_1	Axis_2	Axe_3	Axis_4	Axis_5	Axis_6	Axis_7	Axis_8	leaf_area	leaf_perimeter	Lobe_C_H	Lobe_C_L	Lobe_G_H	Lobe_G_L	Leaf_area_algo	Com.	harvest_fruit	fruit_aborded	Total_ruit	com.
# Axis_1	Axis_2	Axe_3	Axis_4	Axis_5	Axis_6	leaf_area	leaf_perimeter	Lobe_C_H	Lobe_C_L	Lobe_G_H	Lobe_G_L	Leaf_area_algo	Com.	harvest_fruit	fruit_aborded	Total_ruit	com.
# ERROR 3 1 [45]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-afe84ad61ded> in <module>()
# ----> 1 gs = [strawberry2mtg(fn) for fn in files]
#
# z:\g1\marc-labadie\python\strawberry\src\strawberry\reader.pyc in strawberry2mtg(fn)
#     220     """ csv to MTG converter """
#     221     reader = Reader(fn)
# --> 222     g = reader.parse()
#     223     return g
#
# z:\g1\marc-labadie\python\strawberry\src\strawberry\reader.pyc in parse(self)
#     210         self.read()
#     211         self.header()
# --> 212         self.build_mtg()
#     213         return self.g
#     214
#
# z:\g1\marc-labadie\python\strawberry\src\strawberry\reader.pyc in build_mtg(self)
#     202         for i in range(nb_lines):
#     203             #print self._vid
# --> 204             self.read_line()
#     205
#     206         self.g = fat_mtg(g)
#
# z:\g1\marc-labadie\python\strawberry\src\strawberry\reader.pyc in read_line(self)
#     171                 pass
#     172         else:
# --> 173             pid = self._axis_vid[cur_order]
#     174             self._vid = g.add_child(pid, label=label, edge_type='<', **current_props)
#     175             self._axis_vid[cur_order] = self._vid
#
# IndexError: list index out of range

# %%
def compute_pyllochrone(g, dt = 10.):
    max_scale = g.max_scale()
    return g

# %%
from openalea.mtg import traversal
from openalea.mtg.plantframe import turtle
from openalea.plantgl.all import *
# %gui qt

g = gs[0]
g.component_roots_at_scale(g.root, scale=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e2061dccdb89> in <module>()
#       4 get_ipython().magic(u'gui qt')
#       5
# ----> 6 g = gs[0]
#       7 g.component_roots_at_scale(g.root, scale=1)
#
# NameError: name 'gs' is not defined

# %%
def visitor(g, v, turtle):
    """ Function that draw geometry for a given vertex. """
    if g.edge_type(v) == '+':
        turtle.down()
    label = g.label(v)
    print label
    turtle.setId(v)
    if label == 'Phytomer':
        # set color
        len_petiole = 1.
        turtle.F(0.1)
        turtle.push()
        turtle.down()
        turtle.F(len_petiole)
        turtle.circle(1)
        turtle.pop()
    elif label == 'TerminalBud':
        sphere = Sphere(radius=0.2)
        turtle.customGeometry(sphere)
        pass
    turtle.rollL()

scene = turtle.traverse_with_turtle(g, 1, visitor=visitor)
# Out:
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# TerminalBud
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# TerminalBud
# Inflorescence
# Inflorescence
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# TerminalBud
# Inflorescence
# Inflorescence
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Phytomer
# Inflorescence
# Phytomer
# Phytomer
# Phytomer
# Inflorescence
# Inflorescence
# Inflorescence
# Inflorescence

# %%
Viewer.display(scene)

# %%
t = PglTurtle()
