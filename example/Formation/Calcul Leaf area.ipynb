# %%
from collections import OrderedDict, defaultdict
import pandas as pd

from openalea.deploy.shared_data import shared_data
from openalea.mtg import *
from openalea.mtg.algo import orders
from openalea.mtg import stat
import openalea.plantgl.all as pgl
from openalea.core import path
from openalea.mtg import *
from openalea.deploy.shared_data import shared_data
import glob

import openalea.strawberry
from openalea.strawberry import Rules_production
from openalea.strawberry import Visualization, visualisation2d
from openalea.strawberry import analysis, variables
# Out:
#   File "c:\users\mlabadie\miniconda2\envs\openalea\lib\site-packages\openalea.strawberry-1.0.0-py2.7.egg\openalea\strawberry\variables.py", line 233
#     - if stage is other => non defined (pourri, avorté, coupé) (-1)
#                                                                    ^
# SyntaxError: Non-ASCII character '\xc3' in file c:\users\mlabadie\miniconda2\envs\openalea\lib\site-packages\openalea.strawberry-1.0.0-py2.7.egg\openalea\strawberry\variables.py on line 234, but no encoding declared; see http://python.org/dev/peps/pep-0263/ for details

# %%
# %gui qt4

files = shared_data(openalea.strawberry).glob('*.mtg')
# print files

genotypes = dict((f.namebase, f) for f in files)
#print(genotypes.keys())

DIPLOIDS = ['Sicile','Nils']
OCTOPLOIDS = ['Gariguette','Darselect','Clery','Capriss','Cir107','Ciflorette','friendlyfruit', 'friendlyfruit_varieties']

diploids = dict((k,f) for k,f in genotypes.items() if k in DIPLOIDS)
print(diploids)

octoploids = dict((k,f) for k,f in genotypes.items() if k in OCTOPLOIDS)
print(octoploids)
# Out:
# {u'Nils': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Nils.mtg'), u'Sicile': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Sicile.mtg')}
# {u'friendlyfruit': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/friendlyfruit.mtg'), u'friendlyfruit_varieties': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/friendlyfruit_varieties.mtg'), u'Ciflorette': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Ciflorette.mtg'), u'Darselect': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Darselect.mtg'), u'Gariguette': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Gariguette.mtg'), u'Capriss': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Capriss.mtg'), u'Clery': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Clery.mtg'), u'Cir107': Path(u'/Users/pradal/miniconda2/envs/strawberry/lib/python2.7/site-packages/OpenAlea.Strawberry-1.0.0-py2.7.egg/share/data/Cir107.mtg')}

# %%
#OCTOPLOIDS = ['Gariguette_NEW','Darselect_New','Clery_New','Capriss_New''Cir107_NEW','Ciflorette_New']
#DIPLOIDS = ['Sicile_New','Nils_New.mtg']

di_genotype = 'Sicile'
oct_genotype = 'friendlyfruit_varieties'

gdi = MTG(diploids[di_genotype])
print('Diploid  : ', str(gdi))

goct = MTG(octoploids[oct_genotype])
print('Octoploid  : ', str(goct))
# Out:
# replace all the date format by -
# ('Diploid  : ', 'MTG : nb_vertices=4181, nb_scales=4')
# replace all the date format by -
# ('Octoploid  : ', 'MTG : nb_vertices=5318, nb_scales=4')

# %% [markdown]
# # Calcul of leaf area of the plant
#
# ## Octoploid
# __In octoploid__: i use an alometry to calculate leaf area property(LFAR)
#
#     - Alometry: LFAR[v] = 1.89 + (2.145 * LFTLG_CENTRAL[v] * LFTLG_LEFT[v])

# %%
g= goct
g.property_names()
# Out:
# ['LFTWD_LEFT',
#  'Genotype',
#  'Foliar_type',
#  'LFTAR_CENTRAL',
#  'LFTLG_RIGHT',
#  'SAMPLING',
#  'Experiment_name',
#  'edge_type',
#  'LFTWD_CENTRAL',
#  'Architecture_date',
#  'Sample_date',
#  'PETLG',
#  'COMMENT',
#  'index',
#  'Missing',
#  'label',
#  'LFTAR_LEFT',
#  'LFTAR_RIGHT',
#  '_line',
#  'Stade',
#  'LFTLG_LEFT',
#  'LFTWD_RIGHT',
#  'FLWRNUMBER_OPEN',
#  'DBI',
#  'LFAR',
#  'INFLOLG',
#  'Plant_ID',
#  'FLWRNUMBER',
#  'LFTLG_CENTRAL',
#  'FLWRNUMBER_ABORTED',
#  'FLWRNUMBER_CLOSED',
#  'Modality']

# %%
LFTLG_CENTRAL= g.property("LFTLG_CENTRAL")
LFTLG_LEFT= g.property("LFTLG_LEFT")
LFAR= g.property("LFAR")

for v in LFTLG_CENTRAL:
    central = LFTLG_CENTRAL.get(v)
    left = LFTLG_LEFT.get(v)
    
    if (central is None) or (left is None):
        print("DATA is missing on vertex %d for line %d"%(v, g.node(v)._line))
        continue
    LFAR[v] = round(1.89 + (2.145 * central * left),2)

# %%
g.property("LFAR")

# %% [markdown]
# ## Diploid

# %%
g= gdi
g.property_names()
# Out:
# ['LFTWD_LEFT',
#  'Genotype',
#  'Foliar_type',
#  'LFTAR_CENTRAL',
#  'LFTLG_RIGHT',
#  'lenght',
#  'SAMPLING',
#  'Experiment_name',
#  'edge_type',
#  'LFTWD_CENTRAL',
#  'Architecture_date',
#  'Sample_date',
#  'PETLG',
#  'COMMENT',
#  'index',
#  'label',
#  'LFTAR_LEFT',
#  'LFTAR_RIGHT',
#  '_line',
#  'Stade',
#  'LFTLG_LEFT',
#  'LFTWD_RIGHT',
#  'FLWRNUMBER_OPEN',
#  'DBI',
#  'LFAR',
#  'INFLOLG',
#  'Plant_ID',
#  'FLWRNUMBER',
#  'LFTLG_CENTRAL',
#  'FLWRNUMBER_ABORTED',
#  'FLWRNUMBER_CLOSED']

# %%
left = g.property("LFTAR_LEFT")
central = g.property("LFTAR_CENTRAL")
right = g.property("LFTAR_RIGHT")
area = g.property("LFTAR")

print len(left)
print len(central)
print len(right)
print len(area)
# Out:
# 657
# 935
# 660
# 0

# %%
for v in set(list(left) + list(central) + list(right)):
    area[v] = left.get(v,0.) + central.get(v, 0.) + right.get(v, 0.)

area
# Out:
# {3: 49.92,
#  6: 78.462,
#  9: 184.326,
#  12: 291.173,
#  15: 176.684,
#  18: 366.0,
#  21: 356.95399999999995,
#  33: 17.5,
#  36: 31.329,
#  39: 71.861,
#  42: 149.974,
#  45: 362.529,
#  48: 563.912,
#  51: 174.731,
#  60: 5.539,
#  61: 50.227,
#  64: 95.435,
#  67: 166.683,
#  70: 207.27999999999997,
#  73: 229.171,
#  76: 232.231,
#  85: 9.923,
#  88: 73.373,
#  91: 144.55,
#  94: 182.544,
#  97: 425.28,
#  100: 515.732,
#  113: 23.388,
#  116: 33.004,
#  119: 89.461,
#  122: 140.60899999999998,
#  125: 360.091,
#  128: 312.97900000000004,
#  137: 38.9,
#  140: 90.31,
#  143: 116.186,
#  146: 213.552,
#  149: 367.134,
#  152: 539.3770000000001,
#  161: 2.716,
#  164: 24.251,
#  167: 59.465,
#  170: 101.109,
#  173: 268.88300000000004,
#  176: 479.94800000000004,
#  179: 430.607,
#  189: 9.31,
#  192: 12.995,
#  195: 34.594,
#  198: 82.725,
#  201: 127.755,
#  204: 197.99099999999999,
#  207: 288.265,
#  216: 20.687,
#  219: 20.915,
#  222: 104.26,
#  225: 195.118,
#  228: 219.14800000000002,
#  231: 393.031,
#  234: 470.36,
#  243: 6.879,
#  246: 21.977,
#  249: 51.545,
#  252: 84.978,
#  255: 218.072,
#  258: 419.79100000000005,
#  261: 636.929,
#  270: 21.521,
#  273: 31.222,
#  276: 81.948,
#  279: 103.846,
#  282: 197.983,
#  285: 389.08900000000006,
#  288: 457.22900000000004,
#  300: 34.1,
#  303: 36.33,
#  306: 72.33,
#  309: 105.61999999999999,
#  312: 245.07,
#  315: 372.588,
#  324: 21.92,
#  327: 31.07,
#  330: 70.11,
#  333: 171.02,
#  336: 539.3,
#  339: 790.5999999999999,
#  377: 26.15,
#  380: 59.0,
#  383: 124.92,
#  386: 239.5,
#  389: 268.29,
#  398: 15.67,
#  401: 34.6,
#  404: 68.7,
#  407: 76.77,
#  410: 189.45,
#  413: 226.55,
#  416: 358.74,
#  425: 21.88,
#  428: 47.99,
#  431: 93.11,
#  434: 334.54,
#  437: 759.5,
#  440: 994.9100000000001,
#  449: 18.01,
#  452: 55.34,
#  455: 83.63,
#  458: 104.18,
#  461: 344.36,
#  464: 769.67,
#  467: 813.2599999999999,
#  476: 6.05,
#  478: 21.03,
#  481: 22.24,
#  484: 19.39,
#  487: 31.07,
#  490: 132.44,
#  493: 234.27999999999997,
#  496: 262.45,
#  511: 31.0,
#  514: 77.2,
#  517: 88.52000000000001,
#  520: 104.3,
#  529: 27.32,
#  532: 42.86,
#  535: 96.81,
#  538: 215.96,
#  541: 590.92,
#  544: 959.94,
#  553: 37.87,
#  556: 96.19,
#  559: 186.73,
#  562: 344.24,
#  565: 602.53,
#  568: 769.24,
#  577: 25.73,
#  580: 32.61,
#  583: 73.05,
#  586: 197.59000000000003,
#  589: 544.91,
#  592: 360.37,
#  601: 48.77,
#  604: 126.68,
#  607: 198.85,
#  610: 427.93,
#  613: 978.8,
#  616: 1501.28,
#  627: 42.7,
#  630: 112.63,
#  633: 147.78,
#  636: 248.49999999999997,
#  639: 413.93,
#  642: 569.14,
#  652: 40.404,
#  655: 47.197,
#  658: 89.411,
#  661: 170.034,
#  664: 271.356,
#  667: 262.767,
#  679: 23.852,
#  682: 12.382,
#  685: 51.702,
#  688: 121.05499999999999,
#  691: 408.764,
#  694: 304.48199999999997,
#  703: 45.7,
#  706: 130.913,
#  709: 230.404,
#  712: 509.095,
#  715: 620.469,
#  724: 63.74,
#  727: 159.17,
#  730: 384.27,
#  733: 615.17,
#  736: 526.4300000000001,
#  745: 10.32,
#  748: 18.39,
#  751: 53.88,
#  754: 109.8,
#  757: 194.33,
#  760: 346.34,
#  763: 379.93999999999994,
#  772: 6.273,
#  775: 6.729,
#  778: 27.744,
#  781: 80.109,
#  784: 239.721,
#  787: 464.14300000000003,
#  790: 539.797,
#  799: 23.12,
#  802: 86.26,
#  805: 149.11,
#  808: 213.26999999999998,
#  811: 293.0,
#  814: 382.28,
#  826: 19.53,
#  829: 30.23,
#  832: 47.33,
#  841: 85.72,
#  844: 202.0,
#  847: 288.62,
#  850: 314.87,
#  853: 397.38,
#  856: 325.54999999999995,
#  865: 13.06,
#  868: 30.04,
#  871: 23.85,
#  874: 84.14,
#  877: 139.74,
#  880: 215.26999999999998,
#  883: 324.53999999999996,
#  886: 268.66,
#  895: 19.5,
#  898: 37.32,
#  901: 51.85,
#  904: 142.22,
#  907: 196.89,
#  910: 224.18,
#  913: 330.4,
#  916: 330.5,
#  928: 22.71,
#  931: 42.55,
#  934: 52.62,
#  937: 146.07999999999998,
#  940: 239.47,
#  943: 341.34,
#  946: 382.83,
#  949: 427.75,
#  961: 16.86,
#  964: 29.87,
#  967: 39.92,
#  970: 127.66000000000001,
#  973: 208.72,
#  976: 302.41,
#  979: 360.06,
#  982: 396.74,
#  993: 30.82,
#  996: 52.94,
#  999: 57.84,
#  1002: 152.17,
#  1005: 222.98999999999998,
#  1008: 311.89,
#  1011: 359.34000000000003,
#  1014: 346.11,
#  1027: 11.69,
#  1030: 26.27,
#  1033: 23.93,
#  1036: 84.62,
#  1039: 143.16,
#  1042: 195.48000000000002,
#  1045: 250.39,
#  1048: 251.77,
#  1051: 166.52,
#  1060: 20.27,
#  1063: 35.96,
#  1066: 67.99,
#  1069: 167.54999999999998,
#  1072: 248.35000000000002,
#  1075: 252.95000000000002,
#  1078: 314.17,
#  1081: 256.39,
#  1090: 18.52,
#  1093: 23.42,
#  1096: 21.06,
#  1099: 67.62,
#  1102: 96.94,
#  1105: 132.41,
#  1108: 157.64,
#  1111: 223.23000000000002,
#  1123: 26.77,
#  1126: 40.65,
#  1129: 128.97,
#  1132: 194.58,
#  1135: 269.49,
#  1138: 397.18999999999994,
#  1150: 10.97,
#  1153: 35.68,
#  1156: 55.0,
#  1159: 108.21000000000001,
#  1162: 198.51,
#  1165: 290.15999999999997,
#  1168: 329.88,
#  1180: 5.81,
#  1181: 11.81,
#  1184: 15.58,
#  1187: 33.08,
#  1190: 50.68,
#  1193: 141.09,
#  1196: 176.61,
#  1199: 285.54999999999995,
#  1202: 334.28999999999996,
#  1205: 361.70000000000005,
#  1217: 13.55,
#  1220: 37.58,
#  1223: 56.18,
#  1226: 156.13,
#  1229: 242.65999999999997,
#  1232: 339.55,
#  1235: 436.5,
#  1238: 377.02,
#  1247: 8.56,
#  1250: 13.07,
#  1253: 36.84,
#  1256: 54.8,
#  1259: 134.49,
#  1262: 210.2,
#  1265: 293.9,
#  1268: 381.87,
#  1271: 412.33,
#  1274: 162.69,
#  1283: 18.78,
#  1286: 43.84,
#  1289: 60.68,
#  1292: 171.77,
#  1295: 265.56,
#  1298: 331.40999999999997,
#  1301: 413.78,
#  1304: 409.04999999999995,
#  1313: 83.1,
#  1316: 428.31,
#  1319: 926.5500000000001,
#  1322: 1386.98,
#  1325: 1871.42,
#  1328: 1379.6299999999999,
#  1337: 19.31,
#  1340: 19.96,
#  1343: 18.31,
#  1346: 113.53,
#  1352: 431.76,
#  1355: 920.6999999999999,
#  1358: 1156.9499999999998,
#  1361: 970.8399999999999,
#  1370: 9.25,
#  1373: 20.66,
#  1376: 58.95,
#  1379: 148.17,
#  1388: 409.02000000000004,
#  1391: 879.14,
#  1394: 1520.07,
#  1397: 1900.22,
#  1400: 1279.55,
#  1409: 7.72,
#  1412: 16.47,
#  1415: 13.83,
#  1418: 60.71,
#  1424: 247.75,
#  1427: 714.3,
#  1430: 1312.76,
#  1442: 11.58,
#  1445: 25.29,
#  1448: 65.87,
#  1451: 147.98,
#  1454: 503.66999999999996,
#  1457: 1004.48,
#  1460: 1547.8200000000002,
#  1463: 911.9300000000001,
#  1472: 4.59,
#  1473: 12.9,
#  1476: 42.32,
#  1478: 76.95,
#  1482: 244.83,
#  1485: 697.62,
#  1488: 1149.95,
#  1491: 1444.1,
#  1494: 911.22,
#  1503: 11.3,
#  1506: 28.9,
#  1509: 52.8,
#  1512: 142.87,
#  1515: 160.65,
#  1518: 708.36,
#  1521: 1539.41,
#  1524: 1950.3799999999999,
#  1527: 1087.03,
#  1536: 26.03,
#  1539: 92.25,
#  1542: 151.73,
#  1545: 379.43,
#  1548: 647.14,
#  1551: 1183.36,
#  1554: 832.3799999999999,
#  1563: 23.67,
#  1566: 42.6,
#  1569: 108.17,
#  1572: 267.93,
#  1575: 723.14,
#  1578: 1721.06,
#  1581: 1253.0,
#  1584: 1118.8300000000002,
#  1593: 13.94,
#  1596: 31.51,
#  1599: 38.91,
#  1602: 131.53,
#  1605: 372.91999999999996,
#  1608: 701.6800000000001,
#  1611: 1375.77,
#  1614: 1566.67,
#  1617: 995.63,
#  1626: 11.75,
#  1629: 5.77,
#  1632: 52.43,
#  1635: 91.17,
#  1638: 212.26,
#  1641: 708.39,
#  1644: 1111.9,
#  1647: 1506.46,
#  1650: 1242.11,
#  1659: 20.34,
#  1662: 75.09,
#  1665: 53.56,
#  1668: 376.78,
#  1671: 743.5,
#  1674: 810.18,
#  1677: 988.6800000000001,
#  1686: 25.04,
#  1689: 53.21,
#  1692: 112.65,
#  1701: 357.76,
#  1704: 668.29,
#  1707: 1617.46,
#  1710: 2166.62,
#  1713: 2569.43,
#  1716: 769.1700000000001,
#  1725: 9.32,
#  1726: 50.52,
#  1729: 64.04,
#  1732: 109.31,
#  1735: 172.45,
#  1738: 398.75,
#  1741: 769.74,
#  1744: 1317.4299999999998,
#  1747: 1995.6999999999998,
#  1756: 372.74,
#  1759: 931.17,
#  1762: 1817.1999999999998,
#  1765: 2988.2299999999996,
#  1768: 4292.09,
#  1771: 3759.3,
#  1774: 702.56,
#  1789: 44.87,
#  1792: 222.65,
#  1795: 392.23,
#  1798: 1336.6100000000001,
#  1801: 1963.25,
#  1804: 2470.26,
#  1807: 3495.3100000000004,
#  1810: 3122.74,
#  1813: 840.57,
#  1822: 38.91,
#  1825: 132.53,
#  1828: 295.9,
#  1831: 702.1,
#  1834: 1520.55,
#  1837: 2599.8,
#  3529: 114.74,
#  3532: 319.04999999999995,
#  3535: 703.0600000000001,
#  3538: 1282.74,
#  3541: 2000.98,
#  3544: 2707.0499999999997,
#  3547: 3393.84,
#  3550: 2977.2299999999996,
#  3553: 3934.41,
#  3556: 3358.0899999999997,
#  3559: 2585.1,
#  3562: 1093.98,
#  3577: 56.17,
#  3580: 103.04,
#  3583: 272.75,
#  3586: 683.78,
#  3589: 1036.13,
#  3592: 1527.53,
#  3595: 2388.8999999999996,
#  3598: 2745.71,
#  3601: 3236.9500000000003,
#  3604: 2928.2200000000003,
#  3607: 2792.11,
#  3610: 2449.95,
#  3667: 178.56,
#  3670: 394.59000000000003,
#  3673: 741.05,
#  3676: 1275.9299999999998,
#  3679: 1953.6399999999999,
#  3682: 3525.33,
#  3685: 3665.3,
#  3688: 3569.02,
#  3691: 3013.48,
#  3694: 1953.1599999999999,
#  3760: 109.58,
#  3763: 295.48,
#  3766: 410.95000000000005,
#  3769: 922.3199999999999,
#  3772: 2064.46,
#  3775: 3278.2200000000003,
#  3778: 4796.09,
#  3781: 5118.450000000001,
#  3784: 5190.219999999999,
#  3787: 3633.8399999999997,
#  3790: 2221.4300000000003,
#  3808: 73.92,
#  3811: 334.1,
#  3814: 259.41,
#  3817: 1150.19,
#  3820: 2718.31,
#  3823: 4360.71,
#  3826: 4852.37,
#  3829: 4674.44,
#  3832: 4064.6500000000005,
#  3835: 1559.43,
#  3853: 54.69,
#  3856: 132.86,
#  3859: 212.56,
#  3862: 618.28,
#  3865: 731.78,
#  3868: 1006.48,
#  3871: 1980.2000000000003,
#  3874: 2538.78,
#  3877: 1855.79,
#  3880: 907.5300000000001,
#  3898: 241.10000000000002,
#  3901: 476.27,
#  3904: 848.77,
#  3907: 1577.29,
#  3910: 1850.02,
#  3913: 2396.44,
#  3916: 2619.1499999999996,
#  3919: 1198.31,
#  3922: 1153.84,
#  3925: 1218.84,
#  3988: 32.51,
#  3991: 172.85999999999999,
#  3994: 375.13,
#  3997: 1761.6399999999999,
#  4000: 3022.96,
#  4003: 2886.17,
#  4006: 2520.15,
#  4009: 1407.0900000000001,
#  4012: 1104.4299999999998,
#  4015: 1310.77,
#  4033: 44.02,
#  4036: 130.52,
#  4039: 345.86,
#  4042: 862.8799999999999,
#  4045: 1452.45,
#  4048: 2130.94,
#  4051: 2578.95,
#  4054: 2952.2000000000003,
#  4057: 3207.0499999999997,
#  4060: 3020.16,
#  4063: 2996.7,
#  4066: 1993.67,
#  4084: 31.56,
#  4087: 313.79,
#  4090: 581.1899999999999,
#  4093: 1428.66,
#  4096: 2593.14,
#  4099: 2204.8399999999997,
#  4102: 3808.79,
#  4105: 3445.5999999999995,
#  4108: 3528.75,
#  4111: 3106.88,
#  4114: 2287.83,
#  4135: 137.8,
#  4138: 232.59,
#  4141: 276.5,
#  4144: 681.39,
#  4147: 1130.8,
#  4150: 2140.81,
#  4153: 3184.12,
#  4156: 3663.8100000000004,
#  4159: 3413.05,
#  4162: 3463.45,
#  4165: 1860.4099999999999,
#  4168: 1469.77}
