# %%
"""Module import"""

"""Import module of openalea packages"""
from openalea.core import path
from openalea.mtg import *
from openalea.mtg.algo import orders
from openalea.deploy.shared_data import shared_data
import openalea.plantgl.all as pgl

""" Import module of strawberry packages"""
import strawberry
from strawberry import Rules_production
from strawberry import Visualization
from strawberry import Rules_production_Plantule
from strawberry import Visualization_Plantule

""" import module R"""
from rpy2 import *

# %%
% gui qt
files = shared_data(strawberry).glob('*.mtg')
files
# Out:
# [path(u'z:\\g1\\marc-labadie\\python\\strawberry\\share\\data\\Capriss.mtg'),
#  path(u'z:\\g1\\marc-labadie\\python\\strawberry\\share\\data\\Ciflorette.mtg'),
#  path(u'z:\\g1\\marc-labadie\\python\\strawberry\\share\\data\\Clery.mtg'),
#  path(u'z:\\g1\\marc-labadie\\python\\strawberry\\share\\data\\Cir107.mtg'),
#  path(u'z:\\g1\\marc-labadie\\python\\strawberry\\share\\data\\Darselect.mtg'),
#  path(u'z:\\g1\\marc-labadie\\python\\strawberry\\share\\data\\Gariguette.mtg'),
#  path(u'z:\\g1\\marc-labadie\\python\\strawberry\\share\\data\\Nils2.63.39.mtg')]

# %%
#visualisation by Genotype and date
g=MTG(files[6]) 
g.properties()['order'] = orders(g)
Rules_production_Plantule.color_code
scene = Visualization_Plantule.visualise_plants(g)
pgl.Viewer.display(scene)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ec39ddae591e> in <module>()
#       3 g.properties()['order'] = orders(g)
#       4 Rules_production_Plantule.color_code
# ----> 5 scene = Visualization_Plantule.visualise_plants(g)
#       6 pgl.Viewer.display(scene)
#
# z:\g1\marc-labadie\python\strawberry\src\strawberry\Visualization_Plantule.py in visualise_plants(g, vids, positions)
#      52         t = pgl.PglTurtle()
#      53         #t.move(position)
# ---> 54         scene = turtle.traverse_with_turtle(g, vid, visitor=strawberry_visitor, turtle=t, gc=False)
#      55
#      56         ds = scene.todict()
#
# c:\python27\lib\site-packages\openalea\mtg\plantframe\turtle.pyc in traverse_with_turtle(g, vid, visitor, turtle, gc)
#      35     for v in pre_order2_with_filter(g, vid, None, push_turtle, pop_turtle):
#      36         if v == vid: continue
# ---> 37         visitor(g,v,turtle)
#      38     if gc: turtle.stopGC()
#      39     scene = turtle.getScene()
#
# z:\g1\marc-labadie\python\strawberry\src\strawberry\Visualization_Plantule.py in strawberry_visitor(g, v, turtle, time)
#      25
#      26     turtle.setId(v)
# ---> 27     geoms.get(label)(g, v, turtle)
#      28
#      29 #Vizalisation by genotype et par de la date
#
# TypeError: 'NoneType' object is not callable

# %%
""" Merge all MTG to realize au big_MTG with all varieties"""

big_mtg = MTG()
for fn in files:
    big_mtg = algo.union(big_mtg, MTG(fn))
g = big_mtg
genotypes = set(g.property("Genotype").itervalues())
print genotypes
# Out:
# replace all the date format by -
# replace all the date format by -
# replace all the date format by -
# replace all the date format by -
# replace all the date format by -
# replace all the date format by -
# set(['Ciflorette', 'Darselect', 'Gariguette', 'Capriss', 'Clery', 'Nils_2.63.39', 'Cir107'])

# %%
""" Import dataframe"""
from strawberry import analysis
g.properties()['order'] = orders(g)
Rules_production_Plantule.color_code(g)
df = analysis.to_dataframe(g, g.vertices(scale=3))
df
# Out:
#        Fleurs_avorte  Fleurs_ouverte  Fleurs_total  Hauteur_Lobe_centrale_cm  \
# 3                NaN             NaN           NaN                       NaN
# 5                NaN             NaN           NaN                       NaN
# 7                NaN             NaN           NaN                       NaN
# 8                NaN             NaN           NaN                       NaN
# 10               NaN             NaN           NaN                       NaN
# 11               NaN             NaN           NaN                       NaN
# 13               NaN             NaN           NaN                       NaN
# 14               NaN             NaN           NaN                       NaN
# 15               NaN             NaN           NaN                       NaN
# 16               NaN             NaN           NaN                       NaN
# 28                        NaN                 NaN   NaN   NaN     74
# 29                        NaN                 NaN   NaN   NaN     75
# 31                        NaN                 NaN   NaN   NaN     77
# 32                        NaN                 NaN   NaN   NaN     78
# 34                        NaN                 NaN   NaN   NaN     80
# 36                        NaN                 NaN   NaN   NaN     82
# 37                        NaN                 NaN   NaN   NaN     83
# 38                        NaN                 NaN   NaN   NaN     84
# 40                        NaN                 NaN    17   NaN     86
# 41                        NaN                 NaN   NaN   NaN     87
# 43                        NaN                 NaN    17   NaN     89
# 44                        NaN                 NaN     G   NaN     90
# ...                       ...                 ...   ...   ...    ...
# 37618                     7.8                18.4   NaN   NaN   6601
# 37620                     NaN                 NaN   NaN   NaN   6603
# 37622                     NaN                 NaN   NaN   NaN   6605
# 37623                     NaN                 NaN   NaN   NaN   6606
# 37624                     NaN                 NaN   NaN   NaN   6607
# 37625                     NaN                 NaN   NaN   NaN   6608
# 37626                     NaN                 NaN   NaN   NaN   6609
# 37627                     NaN                 NaN    17   NaN   6610
# 37628                     NaN                 NaN    55   NaN   6611
# 37629                     NaN                 NaN    77   NaN   6612
# 37630                     NaN                 NaN    87   NaN   6613
# 37631                     NaN                 NaN    87   NaN   6614
# 37632                     NaN                 NaN    87   NaN   6615
# 37635                     NaN                 NaN   NaN   NaN     51
# 37636                     NaN                 NaN   NaN   NaN     52
# 37637                     NaN                 NaN   NaN   NaN     53
# 37639                     NaN                 NaN   NaN    17     55
# 37640                     NaN                 NaN   NaN   NaN     56
# 37642                     NaN                 NaN   NaN    17     58
# 37643                     NaN                 NaN   NaN   NaN     59
# 37645                     NaN                 NaN   NaN    17     61
# 37646                     NaN                 NaN   NaN   NaN     62
# 37648                     NaN                 NaN   NaN    17     64
# 37649                     NaN                 NaN   NaN   NaN     65
# 37651                     NaN                 NaN   NaN    17     67
# 37652                     NaN                 NaN   NaN   NaN     68
# 37654                     NaN                 NaN   NaN    17     70
# 37655                     NaN                 NaN   NaN   NaN     71
# 37657                     NaN                 NaN   NaN    17     73
# 37658                     NaN                 NaN   NaN    17     74
#
#                  color  complex edge_type  index          label  mesure_ht  \
# 3          (0, 125, 0)        2       NaN      3              F        NaN
# 5        (255, 0, 255)        4         +      5              f        NaN
# 7      (155, 155, 155)        6         +      7             bt        NaN
# 8        (255, 0, 255)        4         <      8              f        NaN
# 10         (0, 255, 0)        9         +     10             bt        NaN
# 11       (255, 0, 255)        4         <     11              f        NaN
# 13       (255, 0, 255)       12         +     13              f        NaN
# 14       (255, 0, 255)       12         <     14              f        NaN
# 15       (255, 145, 0)       12         <     15             ht        NaN
# 16       (255, 217, 0)        4         <     16             ht        NaN
# 17         (0, 125, 0)        2         <     17              F        NaN
# 19       (255, 0, 255)       18         +     19              f        NaN
# 20       (255, 0, 255)       18         <     20              f        NaN
# 21       (255, 0, 255)       18         <     21              f        NaN
# 23         (0, 255, 0)       22         +     23             bt        NaN
# 24       (255, 217, 0)       18         <     24             ht        NaN
# 25         (0, 125, 0)        2         <     25              F        NaN
# 26         (0, 125, 0)        2         <     26              F        NaN
# 28          (0, 20, 0)       27         +     28              s        NaN
# 29         (0, 125, 0)        2         <     29              F        NaN
# 31          (0, 20, 0)       30         +     31              s        NaN
# 32         (0, 125, 0)        2         <     32              F        NaN
# 34       (255, 0, 255)       33         +     34              f        NaN
# 36     (155, 155, 155)       35         +     36             bt        NaN
# 37       (255, 0, 255)       33         <     37              f        NaN
# 38       (255, 0, 255)       33         <     38              f        NaN
# 40         (0, 255, 0)       39         +     40             bt        NaN
# 41       (255, 0, 255)       33         <     41              f        NaN
# 43         (0, 255, 0)       42         +     43             bt        NaN
# 44       (255, 217, 0)       33         <     44             ht        NaN
# ...                ...      ...       ...    ...            ...        ...
# 37618    (255, 0, 255)    37608         <  37618              F        NaN
# 37620    (255, 0, 255)    37619         +  37620              f        NaN
# 37622       (0, 20, 0)    37621         +  37622              s        NaN
# 37623    (255, 0, 255)    37619         <  37623              f        NaN
# 37624    (255, 0, 255)    37619         <  37624              f        NaN
# 37625    (255, 0, 255)    37619         <  37625              f        NaN
# 37626    (255, 0, 255)    37619         <  37626              f        NaN
# 37627      (0, 255, 0)    37619         <  37627             bt        NaN
# 37628    (0, 127, 255)    37608         <  37628             HT        NaN
# 37629    (0, 193, 255)    37595         <  37629             HT        NaN
# 37630    (0, 223, 255)    37553         <  37630             HT        NaN
# 37631    (0, 223, 255)    37530         <  37631             HT        NaN
# 37632    (0, 223, 255)    37408         <  37632             HT        NaN
# 37635              NaN    37634       NaN  37635      Cotyledon        NaN
# 37636              NaN    37634         <  37636      Cotyledon        NaN
# 37637              NaN    37634         <  37637     Unifoliate        NaN
# 37639              NaN    37638         +  37639            Bud        NaN
# 37640              NaN    37634         <  37640     Unifoliate        NaN
# 37642              NaN    37641         +  37642            Bud        NaN
# 37643              NaN    37634         <  37643     Unifoliate        NaN
# 37645              NaN    37644         +  37645            Bud        NaN
# 37646              NaN    37634         <  37646     Trifoliate        NaN
# 37648              NaN    37647         +  37648            Bud        NaN
# 37649              NaN    37634         <  37649     Trifoliate        NaN
# 37651              NaN    37650         +  37651            Bud        NaN
# 37652              NaN    37634         <  37652     Trifoliate        NaN
# 37654              NaN    37653         +  37654            Bud        NaN
# 37655              NaN    37634         <  37655  LeafPrimordia        NaN
# 37657              NaN    37656         +  37657            Bud        NaN
# 37658              NaN    37634         <  37658    TerminalBud        NaN
#
#        order   parent prelevement  scale    vid
# 3          0      NaN         NaN      3      3
# 5          1      3.0         NaN      3      5
# 7          2      5.0         NaN      3      7
# 8          1      5.0         NaN      3      8
# 10         2      8.0         NaN      3     10
# 11         1      8.0         NaN      3     11
# 13         2     11.0         NaN      3     13
# 14         2     13.0         NaN      3     14
# 15         2     14.0         NaN      3     15
# 16         1     11.0         NaN      3     16
# 17         0      3.0         NaN      3     17
# 19         1     17.0         NaN      3     19
# 20         1     19.0         NaN      3     20
# 21         1     20.0         NaN      3     21
# 23         2     21.0         NaN      3     23
# 24         1     21.0         NaN      3     24
# 25         0     17.0         NaN      3     25
# 26         0     25.0         NaN      3     26
# 28         1     26.0         NaN      3     28
# 29         0     26.0         NaN      3     29
# 31         1     29.0         NaN      3     31
# 32         0     29.0         NaN      3     32
# 34         1     32.0         NaN      3     34
# 36         2     34.0         NaN      3     36
# 37         1     34.0         NaN      3     37
# 38         1     37.0         NaN      3     38
# 40         2     38.0         NaN      3     40
# 41         1     38.0         NaN      3     41
# 43         2     41.0         NaN      3     43
# 44         1     41.0         NaN      3     44
# ...      ...      ...         ...    ...    ...
# 37618      4  37612.0         NaN      3  37618
# 37620      5  37618.0         NaN      3  37620
# 37622      6  37620.0         NaN      3  37622
# 37623      5  37620.0         NaN      3  37623
# 37624      5  37623.0         NaN      3  37624
# 37625      5  37624.0         NaN      3  37625
# 37626      5  37625.0         NaN      3  37626
# 37627      5  37626.0       11:37      3  37627
# 37628      4  37618.0         NaN      3  37628
# 37629      3  37607.0         NaN      3  37629
# 37630      2  37594.0         NaN      3  37630
# 37631      1  37552.0         NaN      3  37631
# 37632      0  37529.0         NaN      3  37632
# 37635      0      NaN         NaN      3  37635
# 37636      0  37635.0         NaN      3  37636
# 37637      0  37636.0         NaN      3  37637
# 37639      1  37637.0         NaN      3  37639
# 37640      0  37637.0         NaN      3  37640
# 37642      1  37640.0         NaN      3  37642
# 37643      0  37640.0         NaN      3  37643
# 37645      1  37643.0         NaN      3  37645
# 37646      0  37643.0         NaN      3  37646
# 37648      1  37646.0         NaN      3  37648
# 37649      0  37646.0         NaN      3  37649
# 37651      1  37649.0         NaN      3  37651
# 37652      0  37649.0         NaN      3  37652
# 37654      1  37652.0         NaN      3  37654
# 37655      0  37652.0         NaN      3  37655
# 37657      1  37655.0         NaN      3  37657
# 37658      0  37655.0         NaN      3  37658
#
# [27374 rows x 20 columns]

# %%
"""Visualization of One Plante selected according to Genotype, Plante and date"""
"""Capriss	4	10/12/2014
Capriss	7	07/01/2015
Capriss	5	15/02/2015
Capriss	6	02/03/2015
Capriss	6	03/04/2015
Capriss	4	27/05/2015
"""
"""Identification of Vid (Visitor ID)"""
vid = int(df[df.Genotype=='Capriss'][df.Plante==4][df.date=='10-12-2014'].vid)

"""Visualisattion of the Plant"""
scene=Visualization.visualise_plants(g, [vid], positions=[(0,0,0)])
pgl.Viewer.display(scene)
# Out:
# -c:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#Visualisation some plants selected according to Genotype and Plante or Genotype and date

vids = list(df[df.Genotype=='Capriss'][df.Plante==4].vid.values)
print vids
#vids = list(df[df.Genotype=='Capriss'][df.date=="10-12-2014"].vid.values)

n = len(vids)
n_cols = 1 #selection of number of column for representation
n_rows = n/n_cols+1

dx =2 #Select start point on x axis on the grid
dy = 4 #Select start point on y axis on the grid
y0 = -n_rows*dx /2.
x0 = -n_cols*dy/2.
positions = [(x0+i*dx, y0+j*dy, 0) for i in range(n_cols) for j in range(n_rows)][:n]

scene = Visualization.visualise_plants(g, vids, positions)
pgl.Viewer.display(scene)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d34a09f2f0f7> in <module>()
#       1 #Visualisation some plants selected according to Genotype and Plante or Genotype and date
#       2
# ----> 3 vids = list(df[df.Genotype=='Capriss'][df.Plante==4].vid.values)
#       4 print vids
#       5 #vids = list(df[df.Genotype=='Capriss'][df.date=="10-12-2014"].vid.values)
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Genotype'

# %%
import pandas as pd
sel=pd.read_csv('Z:\G1\Marc-Labadie\Python\strawberry\share\data\plant.selected.csv', sep=';', skiprows=0, index_col=None)
del sel['dist']
sel.Genotype = sel.Genotype.str.strip() 
#sel = sel[sel.Genotype.str.strip()==('Capriss')]


for l in sel.values:
    #print l
    geno, plante, date = l
    vid = df[df.Genotype==geno][df.Plante==plante][df.date==date].vid.values
    #print vid
 
#vid=list(pd.merge(sel,df).vid)

#print len(vid)
#scene=Visualization.visualise_plants(g,vid,positions)
#pgl.Viewer.display(scene)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-fbdf128deda5> in <module>()
#       8 for l in sel.values:
#       9     #print l
# ---> 10     geno, plante, date = l
#      11     vid = df[df.Genotype==geno][df.Plante==plante][df.date==date].vid.values
#      12     #print vid
#
# ValueError: too many values to unpack

# %%
import pandas as pd
sel=pd.read_csv('Z:\G1\Marc-Labadie\Python\strawberry\share\data\Plant.selected.csv', sep=';', skiprows=0, index_col=None)
del sel['dist']
sel.Genotype = sel.Genotype.str.strip() 
#sel = sel[sel.Genotype.str.strip()==('Capris')]
sel_df = pd.merge(sel,df)
sel_df =pd.DataFrame.sort(sel_df,columns= "vid",ascending=True)
#print sel_df

"""Selection of Vids"""
vids= list(sel_df[sel_df.Genotype.isin(["Gariguette"])].vid)
print vids
""" Define position"""
n = len(vids)
n_cols = 1 #selection of number of column for representation
n_rows = n/n_cols

dx =3.5 #Select start point on x axis on the grid
dy = 4 #Select start point on y axis on the grid
y0 = -n_rows*dx /2.
x0 = -n_cols*dy/2.
positions = [(x0+i*dx, y0+j*dy, 0) for i in range(n_cols) for j in range(n_rows)][:n]

"""Visualization function"""
scene=Visualization.visualise_plants(g,vids,positions)
pgl.Viewer.display(scene)
# Out:
# [31679, 32439, 33796, 34745, 35770, 36299]

# %%
sel=pd.read_csv('Z:\G1\Marc-Labadie\Python\strawberry\share\data\Plant.selected.csv', sep=';', skiprows=0, index_col=None)

# %%
sel
# Out:
#       Genotype        date  Plante      dist
# 0      Capriss  10-12-2014       6  2.968351
# 1      Capriss  07-01-2015       7  1.335165
# 2      Capriss  15-02-2015       5  2.061759
# 3      Capriss  02-03-2015       6  2.549550
# 4      Capriss  03-04-2015       6  2.141379
# 5      Capriss  27-05-2015       9  2.142220
# 6   Ciflorette  04-12-2014       6  3.224739
# 7   Ciflorette  07-01-2015       4  1.280702
# 8   Ciflorette  13-02-2015       8  2.221183
# 9   Ciflorette  02-03-2015       3  3.436944
# 10  Ciflorette  30-03-2015       7  0.673684
# 11  Ciflorette  27-05-2015       5  1.847123
# 12      Cir107  10-12-2014       2  1.242857
# 13      Cir107  08-01-2015       4  3.046748
# 14      Cir107  11-02-2015       6  4.386050
# 15      Cir107  04-03-2015       2  1.579632
# 16      Cir107  02-04-2015       2  1.585993
# 17      Cir107  20-05-2015       2  3.490767
# 18       Clery  10-12-2014       3  2.077941
# 19       Clery  07-01-2015       8  2.105085
# 20       Clery  15-02-2015       5  2.736575
# 21       Clery  02-03-2015       6  0.897199
# 22       Clery  03-04-2015       1  2.561830
# 23       Clery  27-05-2015       4  2.166234
# 24   Darselect  10-12-2014       2  5.050000
# 25   Darselect  09-01-2015       1  6.497829
# 26   Darselect  11-02-2015       4  3.069720
# 27   Darselect  06-03-2015       4  3.776728
# 28   Darselect  03-04-2015       5  3.659523
# 29   Darselect  20-05-2015       8  1.782609
# 30  Gariguette  10-12-2014       9  1.493984
# 31  Gariguette  08-01-2015       6  2.238794
# 32  Gariguette  12-02-2015       8  0.751222
# 33  Gariguette  06-03-2015       8  3.073996
# 34  Gariguette  02-04-2015       7  1.498406
# 35  Gariguette  19-05-2015       1  1.290126

# %%
df
# Out:
#          Genotype  Plante  _line  complex        date  diam_mm  index label  \
# 1         Capriss       1     47        0  10-12-2014      NaN      1     P
# 118       Capriss       2    167        0  10-12-2014      NaN    118     P
# 209       Capriss       3    260        0  10-12-2014      NaN    209     P
# 263       Capriss       4    315        0  10-12-2014      NaN    263     P
# 340       Capriss       5    394        0  10-12-2014      NaN    340     P
# 434       Capriss       6    490        0  10-12-2014      NaN    434     P
# 522       Capriss       7    579        0  10-12-2014      NaN    522     P
# 602       Capriss       8    660        0  10-12-2014      NaN    602     P
# 667       Capriss       9    726        0  10-12-2014      NaN    667     P
# 752       Capriss       1    813        0  07-01-2015      NaN    752     P
# 833       Capriss       2    895        0  07-01-2015      NaN    833     P
# 954       Capriss       3   1019        0  07-01-2015      NaN    954     P
# 1071      Capriss       4   1138        0  07-01-2015      NaN   1071     P
# 1244      Capriss       5   1312        0  07-01-2015      NaN   1244     P
# 1343      Capriss       6   1412        0  07-01-2015      NaN   1343     P
# 1464      Capriss       7   1534        0  07-01-2015      NaN   1464     P
# 1583      Capriss       8   1654        0  07-01-2015      NaN   1583     P
# 1698      Capriss       9   1770        0  07-01-2015      NaN   1698     P
# 1794      Capriss       1   1867        0  15-02-2015      NaN   1794     P
# 1913      Capriss       2   1989        0  15-02-2015      NaN   1913     P
# 2077      Capriss       3   2154        0  15-02-2015      NaN   2077     P
# 2238      Capriss       4   2316        0  15-02-2015      NaN   2238     P
# 2314      Capriss       5   2393        0  15-02-2015      NaN   2314     P
# 2462      Capriss       6   2543        0  15-02-2015      NaN   2462     P
# 2594      Capriss       7   2677        0  15-02-2015      NaN   2594     P
# 2673      Capriss       8   2757        0  15-02-2015      NaN   2673     P
# 2796      Capriss       9   2881        0  15-02-2015      NaN   2796     P
# 2990      Capriss       1   3076        0  02-03-2015      NaN   2990     P
# 3118      Capriss       2   3205        0  02-03-2015      NaN   3118     P
# 3212      Capriss       3   3300        0  02-03-2015      NaN   3212     P
# ...           ...     ...    ...      ...         ...      ...    ...   ...
# 33721  Gariguette       7   2674        0  12-02-2015      NaN  33721     P
# 33796  Gariguette       8   2750        0  12-02-2015      NaN  33796     P
# 33908  Gariguette       9   2863        0  12-02-2015      NaN  33908     P
# 34014  Gariguette       1   2970        0  06-03-2015      NaN  34014     P
# 34105  Gariguette       2   3062        0  06-03-2015      NaN  34105     P
# 34193  Gariguette       3   3151        0  06-03-2015      NaN  34193     P
# 34312  Gariguette       4   3271        0  06-03-2015      NaN  34312     P
# 34442  Gariguette       5   3402        0  06-03-2015      NaN  34442     P
# 34559  Gariguette       6   3520        0  06-03-2015      NaN  34559     P
# 34671  Gariguette       7   3633        0  06-03-2015      NaN  34671     P
